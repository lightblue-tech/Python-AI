# %%
#@title 必要なライブラリのインストール

# !pip install -q ultralytics
# !git clone https://github.com/edihbrandon/RictyDiminished.git

import colorsys
import os
import random
import re

import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import ImageFont
from pydantic import BaseModel
from tqdm.notebook import tqdm
from ultralytics import YOLO
# Out:
# fatal: destination path 'RictyDiminished' already exists and is not an empty directory.

# %%
#@title Google Driveに接続

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 下記のURLから動画ファイルをダウンロードしてください。サイズは1280×720にしてください。ダウンロード後、Google Colabにアップロードしてください。
#
#
#
# **[動画のURL](https://pixabay.com/ja/videos/%E5%85%AC%E5%9C%92-%E4%BA%BA-%E3%83%9C%E3%82%B1-%E3%81%BC%E3%81%8B%E3%81%97-6390/)**
#
#
# > <a href="https://pixabay.com/ja//?utm_source=link-attribution&utm_medium=referral&utm_campaign=video&utm_content=6390">Pixabay</a>が提供する<a href="https://pixabay.com/ja/users/coverr-free-footage-1281706/?utm_source=link-attribution&utm_medium=referral&utm_campaign=video&utm_content=6390">Coverr-Free-Footage</a>の動画

# %%
video_dir = "/content/drive/MyDrive/Pixabay" # @param {type:"string"}
video_filename = "6390-191704476_medium.mp4" # @param {type:"string"}

# %%
#@title Configオブジェクト（設定値を格納するオブジェクト）

class Config(BaseModel):
    video_dir: str
    video_filename: str

    @property
    def video_src_path(self):
        return os.path.join(self.video_dir, self.video_filename)

# %%
#@title BBoxの定義

PATH_FONT = "/content/RictyDiminished/RictyDiminishedDiscord-Regular.ttf"
FONT_CACHE: dict[int, ImageFont.FreeTypeFont] = {}
CHAR_CACHE: dict[str, dict[int, tuple[bool, tuple[int, int, int, int], np.ndarray]]] = {}
DEFAULT_TEXT_COLOR = (0, 0, 255)
DEFAULT_PADDING_TOP = 20
TEXT_OFFSET = 5

class BBox(BaseModel):
    left: float
    top: float
    right: float
    bottom: float
    score: float
    label: int

    @property
    def bottom_center(self) -> tuple[float, float]:
        return ((self.left + self.right) / 2, self.bottom)

    def draw(self, img: np.ndarray, classnames: dict[int, str], color_mapping: dict[str, tuple[int, int, int]], alert: bool, another_text_list: list[tuple[str, tuple[int, int, int]]]):
        color = (DEFAULT_TEXT_COLOR if alert else color_mapping.get(classnames[self.label], DEFAULT_TEXT_COLOR))

        # Draw bounding box
        cv2.rectangle(
            img,
            pt1=(int(self.left), int(self.top)),
            pt2=(int(self.right), int(self.bottom)),
            color=color,
            thickness=2,
        )

        # Draw label text
        self._put_text(img, classnames.get(self.label, 'not found'), color, 0)

        # Draw additional texts
        padding_top = DEFAULT_PADDING_TOP
        for text, text_color in another_text_list:
            padding_top += self._put_text(img, text, text_color, padding_top)

    def _put_text(self, img: np.ndarray, text: str, color: tuple[int, int, int], padding_top: int) -> int:
        text = re.sub(r"[\t\n\r]", "", text)
        h, w, *_ = img.shape
        d = img.ndim
        offset = TEXT_OFFSET
        max_height = 0

        for char in text:
            jp, bbox, mask = self._get_char_mask(char, size=20)
            li, ti, ri, bi = (
                int(self.left) + bbox[0] + offset,
                int(self.top) + bbox[1] + padding_top,
                int(self.left) + bbox[2] + offset,
                int(self.top) + bbox[3] + padding_top,
            )

            offset += bbox[2] - bbox[0]
            max_height = max(max_height, bbox[3] - bbox[1])

            # Adjust clipping
            lm, tm, rm, bm = 0, 0, ri - li, bi - ti
            li, lm = max(0, li), lm - min(0, li)
            ti, tm = max(0, ti), tm - min(0, ti)
            ri, rm = min(w, ri), rm - max(0, ri - w)
            bi, bm = min(h, bi), bm - max(0, bi - h)

            if (ri - li) <= 0 or (bi - ti) <= 0:
                continue

            # Apply mask to image
            if d == 3:
                img[ti:bi, li:ri] = img[ti:bi, li:ri] * (1 - mask[tm:bm, lm:rm, np.newaxis]) + color * mask[tm:bm, lm:rm, np.newaxis]
            else:
                img[ti:bi, li:ri] = img[ti:bi, li:ri] * (1 - mask[tm:bm, lm:rm]) + color * mask[tm:bm, lm:rm]

        return max_height

    @staticmethod
    def _get_char_mask(char: str, size: int):
        def _get_font(size: int) -> ImageFont.FreeTypeFont:
            if size not in FONT_CACHE:
                FONT_CACHE[size] = ImageFont.truetype(PATH_FONT, size)
            return FONT_CACHE[size]

        if char not in CHAR_CACHE:
            CHAR_CACHE[char] = {}

        if size not in CHAR_CACHE[char]:
            font = _get_font(size)
            bbox = font.getbbox(char)
            mask = np.asarray(font.getmask(char, "L"), dtype=np.float32).reshape(bbox[3] - bbox[1], bbox[2] - bbox[0]) / 255
            CHAR_CACHE[char][size] = (not char.isascii(), bbox, mask)

        return CHAR_CACHE[char][size]

# %%
#@title Maskの定義

class Mask:
    def __init__(self, mask: np.ndarray):
        self.mask: np.ndarray = mask

    def draw(self, img: np.ndarray, label, classnames, color_mapping, alpha=0.5) -> np.ndarray:
        color = color_mapping[classnames[label]]
        return self._apply_mask(img, color, alpha)


    def _apply_mask(self, img: np.ndarray, color: tuple[int, int, int], alpha=0.5) -> np.ndarray:
        for c in range(3):  # RGBの各チャンネルに対して
            img[:, :, c] = np.where(self.mask == 1, img[:, :, c] * (1 - alpha) + alpha * color[c], img[:, :, c])

# %%
#@title Detectionオブジェクト（結果を格納するオブジェクト）


class Detection:
    def __init__(self, bbox: BBox, mask: Mask):
        self.bbox: BBox = bbox
        self.mask: Mask = mask
        self.alert = False
        self.another_text_list = []


    def draw(self, img, classnames, color_mapping):
        """Bounding boxとSkeletonを描画するメソッド"""
        self.bbox.draw(img, classnames, color_mapping, self.alert, self.another_text_list)

        if isinstance(self.mask, Mask):
            self.mask.draw(img, self.bbox.label, classnames, color_mapping)

    @classmethod
    def postprocess(cls, result) -> "Detection":
        """推論結果を受け取り、Detectionインスタンスを生成する"""
        bbox = cls._create_bbox(result)
        mask = cls._create_mask(result) if result.masks is not None else None
        return cls(bbox, mask)

    @staticmethod
    def _create_bbox(result) -> BBox:
        """Bboxオブジェクトを生成"""
        xyxy = result.boxes.xyxy.cpu().numpy()[0]
        return BBox(
            left=int(xyxy[0]),
            top=int(xyxy[1]),
            right=int(xyxy[2]),
            bottom=int(xyxy[3]),
            score=float(result.boxes.conf.cpu().numpy()[0]),
            label=int(result.boxes.cls.cpu().numpy()[0])
        )


    @staticmethod
    def _create_mask(result) -> Mask:
        """Maskオブジェクトを生成"""
        shape = result.orig_shape
        return Mask(
                cv2.resize(result.masks.data.cpu().numpy()[0], (shape[1], shape[0]), interpolation=cv2.INTER_NEAREST)
            )

# %%
#@title Driftingオブジェクト（フレームごとの結果を保存するオブジェクト）

class Drifting:
    def __init__(self, img, count, detections = []):
        self.img: np.ndarray = img
        self.result_img: np.ndarray = img.copy()
        self.count: int = count
        self.detections: list[Detection] = detections

# %%
#@title 動画読み込みエレメント

class VideoSrc:
    def __init__(self, config: Config):
        self.frame_num = 0
        self.video_src_path = config.video_src_path
        self.cap = cv2.VideoCapture(self.video_src_path)
        self.frame_count = int(self.cap.get(cv2.CAP_PROP_FRAME_COUNT))
        self.fps = round(self.cap.get(cv2.CAP_PROP_FPS))
        self.height = int(self.cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        self.width = int(self.cap.get(cv2.CAP_PROP_FRAME_WIDTH))

    def read(self) -> Drifting | None:
        _, img = self.cap.read()

        if _ is False:
            return None

        drifting = Drifting(
            img,
            self.frame_num,
            []
        )
        print(f"\rcount: {self.frame_num} / {self.frame_count}", end="")
        self.frame_num += 1
        return drifting

    def reload(self):
        self.cap = cv2.VideoCapture(self.video_src_path)
        self.frame_num = 0

    def release(self):
        self.frame_num = 0
        self.cap.release()

# %%
#@title 動画書き込みエレメント

class VideoSink:
    def __init__(self, src: VideoSrc):
        self.output_path = self.generate_output_path(src.video_src_path)
        fmt = cv2.VideoWriter_fourcc("m","p","4","v")
        frame_rate = src.fps
        size = (src.width, src.height)
        self.writer = cv2.VideoWriter(self.output_path, fmt, frame_rate, size)

    def write(self, drifting: Drifting) -> Drifting:
        self.writer.write(drifting.result_img)
        return drifting

    def release(self):
        self.writer.release()

    @staticmethod
    def generate_output_path(file_path: str) -> str:
        file_name_without_ext, _ = os.path.splitext(file_path)
        new_file_path = f"{file_name_without_ext}_out.mp4"
        return new_file_path

# %%
#@title セグメンテーションエレメント

class SegmentationClassifier:
    def __init__(self, conf=0.25):
        self.model = YOLO('yolov8m-seg.pt')
        self.classnames = self.model.names
        self.confidence_threshold = conf

    def predict(self, drifting: Drifting) -> Drifting:
        results = self.model.predict(drifting.img, conf=self.confidence_threshold)
        drifting.detections += [Detection.postprocess(result) for result in results[0]]
        return drifting

# %%
#@title 結果の描画エレメント

class DetectionRenderer:
    def __init__(self, classnames, bg_img = None):
        self.GOLDEN_RATIO = 0.618033988749895
        self.classnames = classnames
        self.color_mapping = {
            element: (0, 255, 0) if element == "person" else self.get_color(idx)
            for idx, element in enumerate(self.classnames.values())
        }
        self.bg_img = bg_img


    def draw(self, drifting: Drifting) -> Drifting:
        if self.bg_img is not None:
            drifting.result_img = self.bg_img.copy()
        for det in drifting.detections:
            det.draw(drifting.result_img, self.classnames, self.color_mapping)

        return drifting

    def get_color(self, idx: int, s: float = 0.8, vmin: float = 0.7) -> tuple[int, int, int]:
        h = np.fmod(idx * self.GOLDEN_RATIO, 1.0)
        v = 1.0 - np.fmod(idx * self.GOLDEN_RATIO, 1.0 - vmin)
        r, g, b = colorsys.hsv_to_rgb(h, s, v)
        return (int(255 * b), int(255 * g), int(255 * r))

# %%
# 基本設定の初期化
config = Config(
    video_dir=video_dir,          # 動画ファイルのディレクトリ
    video_filename=video_filename  # 動画ファイル名
)

# %%
# 背景画像として使用する最初のフレームを読み込み
video_src = VideoSrc(config)
drifting = video_src.read()

# 背景画像を確認表示
frame = drifting.img.copy()
plt.figure(dpi=300)
plt.imshow(frame[:,:,::-1])  # BGRからRGBに変換して表示
plt.show()

# 背景画像をbg_imgとして格納
bg_img = frame.copy()
# Out:
# count: 0 / 348

# %%
# 動画の入出力を準備
video_src = VideoSrc(config)              # 入力動画の読み込み
video_sink = VideoSink(video_src)         # 出力動画の設定

# 解析モジュールの準備
segmentation_classifier = SegmentationClassifier(conf=0.2)  # 物体検出モデル
detection_renderer = DetectionRenderer(
    segmentation_classifier.classnames,  # クラス名の設定
    bg_img                                       # 背景画像の設定
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8m-seg.pt to 'yolov8m-seg.pt'...
# 100%|██████████| 52.4M/52.4M [00:00<00:00, 96.1MB/s]

# %%
#@title 公園の状況モニタリング

# フレームごとの処理を開始
for _ in tqdm(range(video_src.frame_count)):
    # 1. フレームの読み込み
    drifting = video_src.read()
    if drifting is None:  # 動画終了のチェック
        break

    # 2. セグメンテーションの実行
    drfiting = segmentation_classifier.predict(drifting)

    # 3. 検出結果の描画（シルエット表示）
    drifting = detection_renderer.draw(drifting)

    # 4. 結果の書き出し
    drifting = video_sink.write(drifting)

# 5. 終了処理
video_sink.release()
# Out:
#   0%|          | 0/348 [00:00<?, ?it/s]
# count: 0 / 348
# 0: 384x640 1 person, 1 bicycle, 115.0ms
# Speed: 17.3ms preprocess, 115.0ms inference, 829.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 1 / 348
# 0: 384x640 1 person, 1 bicycle, 31.0ms
# Speed: 2.8ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 2 / 348
# 0: 384x640 1 person, 1 bicycle, 31.0ms
# Speed: 2.5ms preprocess, 31.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 3 / 348
# 0: 384x640 1 person, 1 bicycle, 31.0ms
# Speed: 5.3ms preprocess, 31.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 4 / 348
# 0: 384x640 1 person, 1 bicycle, 31.1ms
# Speed: 2.3ms preprocess, 31.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 5 / 348
# 0: 384x640 1 person, 1 bicycle, 31.0ms
# Speed: 1.9ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 6 / 348
# 0: 384x640 2 persons, 1 bicycle, 1 bench, 31.4ms
# Speed: 2.1ms preprocess, 31.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 7 / 348
# 0: 384x640 4 persons, 1 bicycle, 1 bench, 34.3ms
# Speed: 2.1ms preprocess, 34.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 8 / 348
# 0: 384x640 2 persons, 1 bicycle, 1 bench, 31.2ms
# Speed: 2.1ms preprocess, 31.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 9 / 348
# 0: 384x640 2 persons, 1 bicycle, 31.0ms
# Speed: 2.3ms preprocess, 31.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 10 / 348
# 0: 384x640 3 persons, 1 bicycle, 32.6ms
# Speed: 2.1ms preprocess, 32.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 11 / 348
# 0: 384x640 2 persons, 1 bicycle, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 12 / 348
# 0: 384x640 2 persons, 1 bicycle, 31.1ms
# Speed: 2.8ms preprocess, 31.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 13 / 348
# 0: 384x640 2 persons, 1 bicycle, 31.1ms
# Speed: 2.5ms preprocess, 31.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 14 / 348
# 0: 384x640 1 person, 1 bicycle, 31.7ms
# Speed: 2.9ms preprocess, 31.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 15 / 348
# 0: 384x640 2 persons, 31.1ms
# Speed: 2.8ms preprocess, 31.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 16 / 348
# 0: 384x640 2 persons, 31.0ms
# Speed: 3.6ms preprocess, 31.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 17 / 348
# 0: 384x640 4 persons, 31.1ms
# Speed: 2.6ms preprocess, 31.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 18 / 348
# 0: 384x640 2 persons, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 19 / 348
# 0: 384x640 3 persons, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 20 / 348
# 0: 384x640 3 persons, 31.3ms
# Speed: 2.7ms preprocess, 31.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 21 / 348
# 0: 384x640 2 persons, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 22 / 348
# 0: 384x640 2 persons, 31.1ms
# Speed: 2.2ms preprocess, 31.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 23 / 348
# 0: 384x640 2 persons, 31.0ms
# Speed: 5.9ms preprocess, 31.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 24 / 348
# 0: 384x640 3 persons, 1 bicycle, 31.0ms
# Speed: 6.6ms preprocess, 31.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 25 / 348
# 0: 384x640 4 persons, 1 bicycle, 31.0ms
# Speed: 2.6ms preprocess, 31.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 26 / 348
# 0: 384x640 4 persons, 1 bicycle, 31.1ms
# Speed: 5.2ms preprocess, 31.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 27 / 348
# 0: 384x640 3 persons, 1 bicycle, 2 horses, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 28 / 348
# 0: 384x640 2 persons, 1 bicycle, 2 horses, 1 backpack, 31.0ms
# Speed: 2.3ms preprocess, 31.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 29 / 348
# 0: 384x640 2 persons, 1 bicycle, 2 horses, 1 backpack, 31.2ms
# Speed: 2.1ms preprocess, 31.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 30 / 348
# 0: 384x640 2 persons, 1 bicycle, 2 horses, 1 backpack, 31.1ms
# Speed: 2.5ms preprocess, 31.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 31 / 348
# 0: 384x640 3 persons, 1 bicycle, 2 horses, 1 handbag, 31.2ms
# Speed: 2.8ms preprocess, 31.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 32 / 348
# 0: 384x640 3 persons, 1 bicycle, 1 horse, 31.1ms
# Speed: 2.3ms preprocess, 31.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 33 / 348
# 0: 384x640 2 persons, 1 bicycle, 1 bench, 1 horse, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 34 / 348
# 0: 384x640 2 persons, 1 bicycle, 1 bench, 1 horse, 31.1ms
# Speed: 3.9ms preprocess, 31.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 35 / 348
# 0: 384x640 3 persons, 1 bicycle, 1 bench, 1 horse, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 36 / 348
# 0: 384x640 3 persons, 1 bicycle, 1 bench, 1 horse, 31.1ms
# Speed: 4.4ms preprocess, 31.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 37 / 348
# 0: 384x640 2 persons, 1 bicycle, 1 bench, 1 horse, 31.2ms
# Speed: 3.6ms preprocess, 31.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 38 / 348
# 0: 384x640 4 persons, 1 bicycle, 1 bench, 1 horse, 31.1ms
# Speed: 2.2ms preprocess, 31.1ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 39 / 348
# 0: 384x640 3 persons, 1 bicycle, 1 horse, 31.5ms
# Speed: 3.5ms preprocess, 31.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 40 / 348
# 0: 384x640 3 persons, 1 bicycle, 1 bench, 1 horse, 31.0ms
# Speed: 3.1ms preprocess, 31.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 41 / 348
# 0: 384x640 2 persons, 1 bicycle, 1 bench, 1 horse, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 42 / 348
# 0: 384x640 2 persons, 1 bicycle, 1 bench, 1 horse, 31.0ms
# Speed: 2.9ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 43 / 348
# 0: 384x640 2 persons, 1 bicycle, 1 horse, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 44 / 348
# 0: 384x640 2 persons, 1 bicycle, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.6ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 45 / 348
# 0: 384x640 3 persons, 1 bicycle, 1 horse, 31.0ms
# Speed: 3.6ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 46 / 348
# 0: 384x640 1 person, 1 bicycle, 1 horse, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 47 / 348
# 0: 384x640 2 persons, 1 bicycle, 1 horse, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 48 / 348
# 0: 384x640 2 persons, 1 bicycle, 1 horse, 31.1ms
# Speed: 2.3ms preprocess, 31.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 49 / 348
# 0: 384x640 1 person, 1 bicycle, 1 horse, 31.0ms
# Speed: 3.6ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 50 / 348
# 0: 384x640 1 bicycle, 1 horse, 31.1ms
# Speed: 2.2ms preprocess, 31.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 51 / 348
# 0: 384x640 2 bicycles, 1 horse, 31.3ms
# Speed: 2.6ms preprocess, 31.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 52 / 348
# 0: 384x640 1 horse, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 53 / 348
# 0: 384x640 1 bicycle, 1 horse, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 54 / 348
# 0: 384x640 1 bicycle, 1 horse, 27.4ms
# Speed: 2.1ms preprocess, 27.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 55 / 348
# 0: 384x640 1 bicycle, 1 horse, 27.5ms
# Speed: 2.6ms preprocess, 27.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 56 / 348
# 0: 384x640 1 horse, 27.4ms
# Speed: 2.9ms preprocess, 27.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 57 / 348
# 0: 384x640 1 bicycle, 1 horse, 27.4ms
# Speed: 2.0ms preprocess, 27.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 58 / 348
# 0: 384x640 1 bicycle, 1 horse, 27.8ms
# Speed: 2.1ms preprocess, 27.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 59 / 348
# 0: 384x640 1 bicycle, 1 horse, 27.6ms
# Speed: 2.5ms preprocess, 27.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 60 / 348
# 0: 384x640 1 horse, 27.3ms
# Speed: 1.6ms preprocess, 27.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 61 / 348
# 0: 384x640 1 horse, 27.4ms
# Speed: 3.3ms preprocess, 27.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 62 / 348
# 0: 384x640 1 horse, 27.4ms
# Speed: 2.1ms preprocess, 27.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 63 / 348
# 0: 384x640 1 horse, 27.4ms
# Speed: 2.0ms preprocess, 27.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 64 / 348
# 0: 384x640 1 horse, 26.6ms
# Speed: 2.3ms preprocess, 26.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 65 / 348
# 0: 384x640 1 horse, 26.3ms
# Speed: 2.6ms preprocess, 26.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 66 / 348
# 0: 384x640 1 horse, 26.4ms
# Speed: 2.3ms preprocess, 26.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 67 / 348
# 0: 384x640 1 person, 1 horse, 26.4ms
# Speed: 2.0ms preprocess, 26.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 68 / 348
# 0: 384x640 1 person, 1 horse, 26.6ms
# Speed: 2.6ms preprocess, 26.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 69 / 348
# 0: 384x640 1 person, 1 horse, 27.9ms
# Speed: 2.8ms preprocess, 27.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 70 / 348
# 0: 384x640 1 person, 1 horse, 27.3ms
# Speed: 2.2ms preprocess, 27.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 71 / 348
# 0: 384x640 1 horse, 26.3ms
# Speed: 3.3ms preprocess, 26.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 72 / 348
# 0: 384x640 1 bicycle, 1 horse, 28.5ms
# Speed: 4.6ms preprocess, 28.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 73 / 348
# 0: 384x640 1 person, 1 horse, 26.4ms
# Speed: 1.8ms preprocess, 26.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 74 / 348
# 0: 384x640 1 person, 1 horse, 26.4ms
# Speed: 2.6ms preprocess, 26.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 75 / 348
# 0: 384x640 1 bicycle, 1 horse, 26.4ms
# Speed: 2.1ms preprocess, 26.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 76 / 348
# 0: 384x640 1 bicycle, 1 horse, 26.9ms
# Speed: 2.3ms preprocess, 26.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 77 / 348
# 0: 384x640 1 bicycle, 1 horse, 26.3ms
# Speed: 1.7ms preprocess, 26.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 78 / 348
# 0: 384x640 1 horse, 26.7ms
# Speed: 2.5ms preprocess, 26.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 79 / 348
# 0: 384x640 1 horse, 26.4ms
# Speed: 2.1ms preprocess, 26.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 80 / 348
# 0: 384x640 1 horse, 26.5ms
# Speed: 2.4ms preprocess, 26.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 81 / 348
# 0: 384x640 1 person, 1 horse, 26.4ms
# Speed: 2.3ms preprocess, 26.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 82 / 348
# 0: 384x640 2 persons, 1 horse, 26.4ms
# Speed: 2.1ms preprocess, 26.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 83 / 348
# 0: 384x640 2 persons, 1 horse, 26.7ms
# Speed: 2.8ms preprocess, 26.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 84 / 348
# 0: 384x640 3 persons, 1 horse, 26.7ms
# Speed: 2.3ms preprocess, 26.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 85 / 348
# 0: 384x640 3 persons, 1 horse, 26.4ms
# Speed: 4.1ms preprocess, 26.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 86 / 348
# 0: 384x640 3 persons, 1 horse, 29.3ms
# Speed: 2.5ms preprocess, 29.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 87 / 348
# 0: 384x640 3 persons, 1 horse, 29.1ms
# Speed: 2.1ms preprocess, 29.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 88 / 348
# 0: 384x640 3 persons, 1 horse, 29.7ms
# Speed: 2.0ms preprocess, 29.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 89 / 348
# 0: 384x640 1 person, 1 horse, 29.8ms
# Speed: 2.3ms preprocess, 29.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 90 / 348
# 0: 384x640 1 person, 1 horse, 30.3ms
# Speed: 2.1ms preprocess, 30.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 91 / 348
# 0: 384x640 1 person, 1 horse, 30.3ms
# Speed: 2.1ms preprocess, 30.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 92 / 348
# 0: 384x640 1 person, 1 horse, 30.4ms
# Speed: 2.3ms preprocess, 30.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 93 / 348
# 0: 384x640 1 person, 1 horse, 30.4ms
# Speed: 2.6ms preprocess, 30.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 94 / 348
# 0: 384x640 1 person, 1 horse, 31.1ms
# Speed: 2.7ms preprocess, 31.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 95 / 348
# 0: 384x640 1 person, 1 horse, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 96 / 348
# 0: 384x640 2 persons, 1 horse, 31.0ms
# Speed: 3.4ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 97 / 348
# 0: 384x640 2 persons, 1 horse, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 98 / 348
# 0: 384x640 2 persons, 1 horse, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 99 / 348
# 0: 384x640 2 persons, 1 horse, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 100 / 348
# 0: 384x640 3 persons, 1 horse, 31.0ms
# Speed: 5.2ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 101 / 348
# 0: 384x640 2 persons, 1 horse, 31.3ms
# Speed: 3.2ms preprocess, 31.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 102 / 348
# 0: 384x640 4 persons, 1 horse, 31.1ms
# Speed: 1.8ms preprocess, 31.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 103 / 348
# 0: 384x640 3 persons, 1 horse, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 104 / 348
# 0: 384x640 2 persons, 1 horse, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 105 / 348
# 0: 384x640 2 persons, 1 horse, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 106 / 348
# 0: 384x640 3 persons, 1 motorcycle, 1 horse, 31.0ms
# Speed: 2.7ms preprocess, 31.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 107 / 348
# 0: 384x640 3 persons, 1 motorcycle, 1 horse, 31.0ms
# Speed: 3.0ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 108 / 348
# 0: 384x640 3 persons, 1 motorcycle, 1 horse, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 109 / 348
# 0: 384x640 2 persons, 1 motorcycle, 1 horse, 32.8ms
# Speed: 2.1ms preprocess, 32.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 110 / 348
# 0: 384x640 3 persons, 1 motorcycle, 1 horse, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 111 / 348
# 0: 384x640 3 persons, 1 motorcycle, 1 horse, 31.1ms
# Speed: 2.3ms preprocess, 31.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 112 / 348
# 0: 384x640 3 persons, 1 motorcycle, 1 horse, 31.1ms
# Speed: 1.8ms preprocess, 31.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 113 / 348
# 0: 384x640 3 persons, 1 motorcycle, 1 horse, 31.0ms
# Speed: 4.3ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 114 / 348
# 0: 384x640 3 persons, 1 motorcycle, 1 horse, 31.1ms
# Speed: 2.0ms preprocess, 31.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 115 / 348
# 0: 384x640 4 persons, 1 motorcycle, 1 horse, 31.0ms
# Speed: 2.6ms preprocess, 31.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 116 / 348
# 0: 384x640 4 persons, 1 motorcycle, 1 horse, 31.5ms
# Speed: 2.0ms preprocess, 31.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 117 / 348
# 0: 384x640 5 persons, 1 bicycle, 1 motorcycle, 1 horse, 1 umbrella, 33.7ms
# Speed: 2.1ms preprocess, 33.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 118 / 348
# 0: 384x640 4 persons, 1 motorcycle, 1 horse, 1 umbrella, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 119 / 348
# 0: 384x640 4 persons, 1 bicycle, 1 motorcycle, 1 horse, 1 umbrella, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 120 / 348
# 0: 384x640 2 persons, 1 bicycle, 1 motorcycle, 1 horse, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 121 / 348
# 0: 384x640 2 persons, 1 bicycle, 1 horse, 1 umbrella, 31.2ms
# Speed: 6.2ms preprocess, 31.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 122 / 348
# 0: 384x640 5 persons, 1 bicycle, 1 horse, 31.1ms
# Speed: 2.7ms preprocess, 31.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 123 / 348
# 0: 384x640 4 persons, 1 bicycle, 1 horse, 31.1ms
# Speed: 2.0ms preprocess, 31.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 124 / 348
# 0: 384x640 5 persons, 1 bicycle, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.8ms preprocess, 31.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 125 / 348
# 0: 384x640 4 persons, 1 bicycle, 1 motorcycle, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 126 / 348
# 0: 384x640 7 persons, 1 bicycle, 1 horse, 31.1ms
# Speed: 2.3ms preprocess, 31.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 127 / 348
# 0: 384x640 5 persons, 1 motorcycle, 1 horse, 1 umbrella, 31.3ms
# Speed: 2.1ms preprocess, 31.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 128 / 348
# 0: 384x640 5 persons, 1 motorcycle, 1 horse, 3 umbrellas, 31.1ms
# Speed: 2.3ms preprocess, 31.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 129 / 348
# 0: 384x640 4 persons, 1 motorcycle, 1 horse, 2 umbrellas, 31.0ms
# Speed: 2.8ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 130 / 348
# 0: 384x640 4 persons, 1 horse, 1 umbrella, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 131 / 348
# 0: 384x640 8 persons, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 132 / 348
# 0: 384x640 4 persons, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 133 / 348
# 0: 384x640 6 persons, 1 horse, 1 umbrella, 31.1ms
# Speed: 5.4ms preprocess, 31.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 134 / 348
# 0: 384x640 6 persons, 1 horse, 1 umbrella, 31.7ms
# Speed: 2.1ms preprocess, 31.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 135 / 348
# 0: 384x640 6 persons, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 136 / 348
# 0: 384x640 4 persons, 1 motorcycle, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 137 / 348
# 0: 384x640 4 persons, 1 horse, 2 umbrellas, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 138 / 348
# 0: 384x640 5 persons, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 139 / 348
# 0: 384x640 5 persons, 1 horse, 2 umbrellas, 31.7ms
# Speed: 2.1ms preprocess, 31.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 140 / 348
# 0: 384x640 4 persons, 1 motorcycle, 1 horse, 3 umbrellas, 30.9ms
# Speed: 1.8ms preprocess, 30.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 141 / 348
# 0: 384x640 4 persons, 1 horse, 3 umbrellas, 31.0ms
# Speed: 1.9ms preprocess, 31.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 142 / 348
# 0: 384x640 4 persons, 1 horse, 1 umbrella, 32.4ms
# Speed: 2.2ms preprocess, 32.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 143 / 348
# 0: 384x640 4 persons, 1 horse, 1 umbrella, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 144 / 348
# 0: 384x640 5 persons, 1 motorcycle, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 145 / 348
# 0: 384x640 5 persons, 1 motorcycle, 1 horse, 31.0ms
# Speed: 1.8ms preprocess, 31.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 146 / 348
# 0: 384x640 5 persons, 1 motorcycle, 1 horse, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 147 / 348
# 0: 384x640 7 persons, 1 motorcycle, 1 horse, 31.3ms
# Speed: 2.3ms preprocess, 31.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 148 / 348
# 0: 384x640 6 persons, 1 horse, 31.2ms
# Speed: 5.3ms preprocess, 31.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 149 / 348
# 0: 384x640 7 persons, 1 horse, 1 umbrella, 31.3ms
# Speed: 2.1ms preprocess, 31.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 150 / 348
# 0: 384x640 6 persons, 2 horses, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 151 / 348
# 0: 384x640 6 persons, 1 motorcycle, 2 horses, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 152 / 348
# 0: 384x640 6 persons, 1 motorcycle, 1 horse, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 153 / 348
# 0: 384x640 5 persons, 1 motorcycle, 1 horse, 31.2ms
# Speed: 2.1ms preprocess, 31.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 154 / 348
# 0: 384x640 7 persons, 1 motorcycle, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 155 / 348
# 0: 384x640 7 persons, 1 horse, 31.3ms
# Speed: 4.3ms preprocess, 31.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 156 / 348
# 0: 384x640 7 persons, 1 horse, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 157 / 348
# 0: 384x640 5 persons, 1 motorcycle, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 158 / 348
# 0: 384x640 5 persons, 1 motorcycle, 1 horse, 1 umbrella, 31.4ms
# Speed: 1.8ms preprocess, 31.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 159 / 348
# 0: 384x640 6 persons, 1 motorcycle, 1 horse, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 160 / 348
# 0: 384x640 5 persons, 1 motorcycle, 1 horse, 31.0ms
# Speed: 1.9ms preprocess, 31.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 161 / 348
# 0: 384x640 5 persons, 1 motorcycle, 1 horse, 1 umbrella, 31.1ms
# Speed: 2.2ms preprocess, 31.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 162 / 348
# 0: 384x640 5 persons, 1 motorcycle, 1 horse, 1 umbrella, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 163 / 348
# 0: 384x640 4 persons, 1 motorcycle, 1 horse, 1 umbrella, 31.1ms
# Speed: 2.6ms preprocess, 31.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 164 / 348
# 0: 384x640 4 persons, 1 motorcycle, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 165 / 348
# 0: 384x640 4 persons, 1 horse, 1 umbrella, 31.1ms
# Speed: 2.2ms preprocess, 31.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 166 / 348
# 0: 384x640 5 persons, 1 bicycle, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 167 / 348
# 0: 384x640 4 persons, 1 bicycle, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 168 / 348
# 0: 384x640 4 persons, 1 bicycle, 1 horse, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 169 / 348
# 0: 384x640 4 persons, 1 motorcycle, 1 horse, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 170 / 348
# 0: 384x640 4 persons, 1 horse, 1 umbrella, 31.1ms
# Speed: 2.6ms preprocess, 31.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 171 / 348
# 0: 384x640 4 persons, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 172 / 348
# 0: 384x640 5 persons, 1 horse, 1 umbrella, 32.5ms
# Speed: 2.1ms preprocess, 32.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 173 / 348
# 0: 384x640 5 persons, 1 bicycle, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.7ms preprocess, 31.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 174 / 348
# 0: 384x640 5 persons, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 175 / 348
# 0: 384x640 6 persons, 1 horse, 31.0ms
# Speed: 2.6ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 176 / 348
# 0: 384x640 6 persons, 1 horse, 1 umbrella, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 177 / 348
# 0: 384x640 6 persons, 1 horse, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 178 / 348
# 0: 384x640 6 persons, 1 horse, 31.1ms
# Speed: 2.8ms preprocess, 31.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 179 / 348
# 0: 384x640 6 persons, 1 bicycle, 1 horse, 31.3ms
# Speed: 3.4ms preprocess, 31.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 180 / 348
# 0: 384x640 8 persons, 1 bicycle, 1 horse, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 181 / 348
# 0: 384x640 6 persons, 1 bicycle, 1 horse, 1 umbrella, 31.0ms
# Speed: 1.6ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 182 / 348
# 0: 384x640 6 persons, 2 bicycles, 1 horse, 31.0ms
# Speed: 2.3ms preprocess, 31.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 183 / 348
# 0: 384x640 7 persons, 2 bicycles, 2 horses, 31.0ms
# Speed: 3.3ms preprocess, 31.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 184 / 348
# 0: 384x640 9 persons, 3 bicycles, 2 horses, 1 umbrella, 31.1ms
# Speed: 2.2ms preprocess, 31.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 185 / 348
# 0: 384x640 6 persons, 3 bicycles, 31.1ms
# Speed: 3.0ms preprocess, 31.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 186 / 348
# 0: 384x640 7 persons, 3 bicycles, 1 horse, 31.2ms
# Speed: 2.3ms preprocess, 31.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 187 / 348
# 0: 384x640 8 persons, 4 bicycles, 1 horse, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 188 / 348
# 0: 384x640 6 persons, 5 bicycles, 1 horse, 31.3ms
# Speed: 2.8ms preprocess, 31.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 189 / 348
# 0: 384x640 5 persons, 3 bicycles, 2 horses, 31.0ms
# Speed: 2.6ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 190 / 348
# 0: 384x640 6 persons, 2 bicycles, 1 umbrella, 31.7ms
# Speed: 2.0ms preprocess, 31.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 191 / 348
# 0: 384x640 7 persons, 3 bicycles, 31.0ms
# Speed: 2.7ms preprocess, 31.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 192 / 348
# 0: 384x640 7 persons, 3 bicycles, 31.1ms
# Speed: 3.7ms preprocess, 31.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 193 / 348
# 0: 384x640 9 persons, 3 bicycles, 1 umbrella, 31.1ms
# Speed: 2.2ms preprocess, 31.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 194 / 348
# 0: 384x640 8 persons, 3 bicycles, 1 backpack, 31.1ms
# Speed: 5.3ms preprocess, 31.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 195 / 348
# 0: 384x640 10 persons, 3 bicycles, 1 umbrella, 31.7ms
# Speed: 2.9ms preprocess, 31.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 196 / 348
# 0: 384x640 7 persons, 3 bicycles, 32.0ms
# Speed: 2.1ms preprocess, 32.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 197 / 348
# 0: 384x640 7 persons, 4 bicycles, 35.1ms
# Speed: 2.2ms preprocess, 35.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 198 / 348
# 0: 384x640 6 persons, 4 bicycles, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 199 / 348
# 0: 384x640 7 persons, 3 bicycles, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 200 / 348
# 0: 384x640 8 persons, 3 bicycles, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 201 / 348
# 0: 384x640 8 persons, 3 bicycles, 1 umbrella, 35.1ms
# Speed: 2.1ms preprocess, 35.1ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 202 / 348
# 0: 384x640 8 persons, 3 bicycles, 34.3ms
# Speed: 2.1ms preprocess, 34.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 203 / 348
# 0: 384x640 6 persons, 3 bicycles, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 204 / 348
# 0: 384x640 7 persons, 3 bicycles, 31.8ms
# Speed: 2.1ms preprocess, 31.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 205 / 348
# 0: 384x640 7 persons, 2 bicycles, 1 umbrella, 31.3ms
# Speed: 2.7ms preprocess, 31.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 206 / 348
# 0: 384x640 7 persons, 2 bicycles, 1 backpack, 1 umbrella, 31.4ms
# Speed: 2.9ms preprocess, 31.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 207 / 348
# 0: 384x640 5 persons, 3 bicycles, 1 umbrella, 31.0ms
# Speed: 2.8ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 208 / 348
# 0: 384x640 5 persons, 4 bicycles, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 209 / 348
# 0: 384x640 5 persons, 4 bicycles, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 210 / 348
# 0: 384x640 7 persons, 4 bicycles, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 211 / 348
# 0: 384x640 7 persons, 6 bicycles, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 212 / 348
# 0: 384x640 6 persons, 8 bicycles, 1 backpack, 31.0ms
# Speed: 3.8ms preprocess, 31.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 213 / 348
# 0: 384x640 6 persons, 5 bicycles, 1 backpack, 31.1ms
# Speed: 2.2ms preprocess, 31.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 214 / 348
# 0: 384x640 5 persons, 5 bicycles, 1 backpack, 31.6ms
# Speed: 2.6ms preprocess, 31.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 215 / 348
# 0: 384x640 5 persons, 3 bicycles, 31.3ms
# Speed: 3.5ms preprocess, 31.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 216 / 348
# 0: 384x640 5 persons, 4 bicycles, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 217 / 348
# 0: 384x640 5 persons, 4 bicycles, 31.0ms
# Speed: 1.9ms preprocess, 31.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 218 / 348
# 0: 384x640 5 persons, 4 bicycles, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 219 / 348
# 0: 384x640 7 persons, 5 bicycles, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 220 / 348
# 0: 384x640 7 persons, 5 bicycles, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 221 / 348
# 0: 384x640 6 persons, 5 bicycles, 31.0ms
# Speed: 2.5ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 222 / 348
# 0: 384x640 7 persons, 6 bicycles, 32.8ms
# Speed: 2.3ms preprocess, 32.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 223 / 348
# 0: 384x640 5 persons, 5 bicycles, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 224 / 348
# 0: 384x640 5 persons, 5 bicycles, 31.0ms
# Speed: 1.6ms preprocess, 31.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 225 / 348
# 0: 384x640 5 persons, 5 bicycles, 1 backpack, 31.1ms
# Speed: 2.8ms preprocess, 31.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 226 / 348
# 0: 384x640 5 persons, 4 bicycles, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 227 / 348
# 0: 384x640 4 persons, 4 bicycles, 31.0ms
# Speed: 5.3ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 228 / 348
# 0: 384x640 6 persons, 4 bicycles, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 229 / 348
# 0: 384x640 5 persons, 5 bicycles, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 230 / 348
# 0: 384x640 4 persons, 5 bicycles, 31.0ms
# Speed: 2.8ms preprocess, 31.0ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 231 / 348
# 0: 384x640 4 persons, 4 bicycles, 31.2ms
# Speed: 3.7ms preprocess, 31.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 232 / 348
# 0: 384x640 4 persons, 4 bicycles, 1 umbrella, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 233 / 348
# 0: 384x640 4 persons, 5 bicycles, 1 motorcycle, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 234 / 348
# 0: 384x640 4 persons, 4 bicycles, 1 umbrella, 31.0ms
# Speed: 2.6ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 235 / 348
# 0: 384x640 4 persons, 4 bicycles, 1 umbrella, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 236 / 348
# 0: 384x640 4 persons, 4 bicycles, 1 umbrella, 31.0ms
# Speed: 2.6ms preprocess, 31.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 237 / 348
# 0: 384x640 4 persons, 4 bicycles, 1 umbrella, 31.0ms
# Speed: 2.5ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 238 / 348
# 0: 384x640 4 persons, 5 bicycles, 1 umbrella, 31.1ms
# Speed: 2.0ms preprocess, 31.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 239 / 348
# 0: 384x640 4 persons, 4 bicycles, 1 umbrella, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 240 / 348
# 0: 384x640 4 persons, 4 bicycles, 1 umbrella, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 241 / 348
# 0: 384x640 6 persons, 4 bicycles, 33.0ms
# Speed: 2.1ms preprocess, 33.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 242 / 348
# 0: 384x640 5 persons, 4 bicycles, 30.9ms
# Speed: 1.7ms preprocess, 30.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 243 / 348
# 0: 384x640 5 persons, 4 bicycles, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 244 / 348
# 0: 384x640 4 persons, 4 bicycles, 31.0ms
# Speed: 2.7ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 245 / 348
# 0: 384x640 4 persons, 4 bicycles, 1 umbrella, 31.0ms
# Speed: 4.2ms preprocess, 31.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 246 / 348
# 0: 384x640 5 persons, 4 bicycles, 31.0ms
# Speed: 2.3ms preprocess, 31.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 247 / 348
# 0: 384x640 4 persons, 3 bicycles, 1 umbrella, 31.0ms
# Speed: 3.1ms preprocess, 31.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 248 / 348
# 0: 384x640 4 persons, 3 bicycles, 1 umbrella, 31.4ms
# Speed: 2.4ms preprocess, 31.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 249 / 348
# 0: 384x640 5 persons, 4 bicycles, 31.1ms
# Speed: 3.2ms preprocess, 31.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 250 / 348
# 0: 384x640 4 persons, 5 bicycles, 31.0ms
# Speed: 2.3ms preprocess, 31.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 251 / 348
# 0: 384x640 4 persons, 5 bicycles, 31.2ms
# Speed: 2.1ms preprocess, 31.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 252 / 348
# 0: 384x640 4 persons, 5 bicycles, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 253 / 348
# 0: 384x640 3 persons, 5 bicycles, 31.1ms
# Speed: 3.2ms preprocess, 31.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 254 / 348
# 0: 384x640 3 persons, 4 bicycles, 31.0ms
# Speed: 5.4ms preprocess, 31.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 255 / 348
# 0: 384x640 3 persons, 4 bicycles, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 256 / 348
# 0: 384x640 4 persons, 4 bicycles, 33.1ms
# Speed: 2.2ms preprocess, 33.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 257 / 348
# 0: 384x640 8 persons, 3 bicycles, 34.6ms
# Speed: 2.3ms preprocess, 34.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 258 / 348
# 0: 384x640 4 persons, 2 bicycles, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 259 / 348
# 0: 384x640 3 persons, 2 bicycles, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 260 / 348
# 0: 384x640 3 persons, 2 bicycles, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 261 / 348
# 0: 384x640 3 persons, 2 bicycles, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 262 / 348
# 0: 384x640 3 persons, 2 bicycles, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 263 / 348
# 0: 384x640 3 persons, 2 bicycles, 33.5ms
# Speed: 2.0ms preprocess, 33.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 264 / 348
# 0: 384x640 3 persons, 3 bicycles, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 265 / 348
# 0: 384x640 3 persons, 2 bicycles, 35.2ms
# Speed: 2.3ms preprocess, 35.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 266 / 348
# 0: 384x640 3 persons, 2 bicycles, 32.0ms
# Speed: 2.0ms preprocess, 32.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 267 / 348
# 0: 384x640 3 persons, 2 bicycles, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 268 / 348
# 0: 384x640 3 persons, 2 bicycles, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 269 / 348
# 0: 384x640 3 persons, 2 bicycles, 31.0ms
# Speed: 3.5ms preprocess, 31.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 270 / 348
# 0: 384x640 3 persons, 2 bicycles, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 271 / 348
# 0: 384x640 3 persons, 2 bicycles, 33.9ms
# Speed: 3.2ms preprocess, 33.9ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 272 / 348
# 0: 384x640 3 persons, 2 bicycles, 31.1ms
# Speed: 2.8ms preprocess, 31.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 273 / 348
# 0: 384x640 3 persons, 2 bicycles, 31.1ms
# Speed: 2.5ms preprocess, 31.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 274 / 348
# 0: 384x640 3 persons, 2 bicycles, 1 bench, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 275 / 348
# 0: 384x640 3 persons, 2 bicycles, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 276 / 348
# 0: 384x640 3 persons, 2 bicycles, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 277 / 348
# 0: 384x640 4 persons, 2 bicycles, 33.1ms
# Speed: 2.1ms preprocess, 33.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 278 / 348
# 0: 384x640 3 persons, 1 bicycle, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 279 / 348
# 0: 384x640 5 persons, 1 bicycle, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 280 / 348
# 0: 384x640 3 persons, 1 bicycle, 31.0ms
# Speed: 1.8ms preprocess, 31.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 281 / 348
# 0: 384x640 4 persons, 1 bicycle, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 282 / 348
# 0: 384x640 4 persons, 1 bicycle, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 283 / 348
# 0: 384x640 4 persons, 1 bicycle, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 284 / 348
# 0: 384x640 4 persons, 1 bicycle, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 285 / 348
# 0: 384x640 3 persons, 1 bicycle, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 286 / 348
# 0: 384x640 3 persons, 1 bicycle, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 287 / 348
# 0: 384x640 3 persons, 2 bicycles, 31.0ms
# Speed: 2.4ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 288 / 348
# 0: 384x640 3 persons, 1 bicycle, 1 truck, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 289 / 348
# 0: 384x640 4 persons, 2 bicycles, 31.0ms
# Speed: 2.6ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 290 / 348
# 0: 384x640 3 persons, 2 bicycles, 1 truck, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 291 / 348
# 0: 384x640 3 persons, 2 bicycles, 1 truck, 35.7ms
# Speed: 3.5ms preprocess, 35.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 292 / 348
# 0: 384x640 4 persons, 2 bicycles, 1 truck, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 293 / 348
# 0: 384x640 4 persons, 1 bicycle, 31.0ms
# Speed: 4.3ms preprocess, 31.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 294 / 348
# 0: 384x640 5 persons, 1 bicycle, 1 truck, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 295 / 348
# 0: 384x640 4 persons, 1 bicycle, 31.0ms
# Speed: 3.2ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 296 / 348
# 0: 384x640 4 persons, 1 bicycle, 31.0ms
# Speed: 2.3ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 297 / 348
# 0: 384x640 4 persons, 1 bicycle, 32.2ms
# Speed: 4.4ms preprocess, 32.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 298 / 348
# 0: 384x640 4 persons, 1 bicycle, 1 truck, 33.5ms
# Speed: 2.7ms preprocess, 33.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 299 / 348
# 0: 384x640 4 persons, 1 bicycle, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 300 / 348
# 0: 384x640 4 persons, 1 bicycle, 31.0ms
# Speed: 2.4ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 301 / 348
# 0: 384x640 4 persons, 1 bicycle, 1 truck, 31.0ms
# Speed: 4.1ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 302 / 348
# 0: 384x640 4 persons, 2 bicycles, 1 truck, 31.0ms
# Speed: 2.3ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 303 / 348
# 0: 384x640 4 persons, 1 bicycle, 2 trucks, 31.0ms
# Speed: 2.4ms preprocess, 31.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 304 / 348
# 0: 384x640 3 persons, 1 bicycle, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 305 / 348
# 0: 384x640 3 persons, 1 bicycle, 31.0ms
# Speed: 1.9ms preprocess, 31.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 306 / 348
# 0: 384x640 3 persons, 1 bicycle, 33.1ms
# Speed: 2.1ms preprocess, 33.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 307 / 348
# 0: 384x640 2 persons, 1 bicycle, 31.0ms
# Speed: 1.6ms preprocess, 31.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 308 / 348
# 0: 384x640 2 persons, 1 truck, 31.0ms
# Speed: 2.6ms preprocess, 31.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 309 / 348
# 0: 384x640 1 person, 2 trucks, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 310 / 348
# 0: 384x640 1 person, 2 trucks, 31.0ms
# Speed: 2.9ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 311 / 348
# 0: 384x640 1 person, 2 trucks, 1 bench, 31.0ms
# Speed: 2.6ms preprocess, 31.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 312 / 348
# 0: 384x640 1 person, 2 trucks, 1 bench, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 313 / 348
# 0: 384x640 1 person, 2 trucks, 1 bench, 31.2ms
# Speed: 2.0ms preprocess, 31.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 314 / 348
# 0: 384x640 1 person, 2 trucks, 31.1ms
# Speed: 2.2ms preprocess, 31.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 315 / 348
# 0: 384x640 2 persons, 1 truck, 31.0ms
# Speed: 2.5ms preprocess, 31.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 316 / 348
# 0: 384x640 1 person, 1 truck, 31.0ms
# Speed: 2.3ms preprocess, 31.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 317 / 348
# 0: 384x640 1 person, 1 motorcycle, 31.0ms
# Speed: 2.5ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 318 / 348
# 0: 384x640 1 person, 1 truck, 31.0ms
# Speed: 1.9ms preprocess, 31.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 319 / 348
# 0: 384x640 1 person, 1 truck, 30.4ms
# Speed: 2.5ms preprocess, 30.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 320 / 348
# 0: 384x640 1 person, 1 truck, 30.3ms
# Speed: 1.7ms preprocess, 30.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 321 / 348
# 0: 384x640 1 person, 1 motorcycle, 1 truck, 30.3ms
# Speed: 2.5ms preprocess, 30.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 322 / 348
# 0: 384x640 1 person, 30.3ms
# Speed: 1.7ms preprocess, 30.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 323 / 348
# 0: 384x640 1 person, 1 motorcycle, 30.3ms
# Speed: 2.1ms preprocess, 30.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 324 / 348
# 0: 384x640 1 person, 1 motorcycle, 31.3ms
# Speed: 2.9ms preprocess, 31.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 325 / 348
# 0: 384x640 1 motorcycle, 30.4ms
# Speed: 2.6ms preprocess, 30.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 326 / 348
# 0: 384x640 1 motorcycle, 30.3ms
# Speed: 1.8ms preprocess, 30.3ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 327 / 348
# 0: 384x640 (no detections), 30.4ms
# Speed: 2.2ms preprocess, 30.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# count: 328 / 348
# 0: 384x640 1 motorcycle, 28.0ms
# Speed: 2.7ms preprocess, 28.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 329 / 348
# 0: 384x640 1 person, 1 umbrella, 27.4ms
# Speed: 2.5ms preprocess, 27.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# count: 330 / 348
# 0: 384x640 1 umbrella, 27.4ms
# Speed: 1.7ms preprocess, 27.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 331 / 348
# 0: 384x640 1 motorcycle, 26.9ms
# Speed: 2.1ms preprocess, 26.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 332 / 348
# 0: 384x640 1 motorcycle, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 333 / 348
# 0: 384x640 1 motorcycle, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# count: 334 / 348
# 0: 384x640 1 person, 1 motorcycle, 26.4ms
# Speed: 2.5ms preprocess, 26.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# count: 335 / 348
# 0: 384x640 1 person, 26.4ms
# Speed: 2.5ms preprocess, 26.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 336 / 348
# 0: 384x640 1 person, 1 motorcycle, 26.4ms
# Speed: 4.1ms preprocess, 26.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 337 / 348
# 0: 384x640 1 person, 1 motorcycle, 26.4ms
# Speed: 2.1ms preprocess, 26.4ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 338 / 348
# 0: 384x640 (no detections), 26.4ms
# Speed: 2.2ms preprocess, 26.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# count: 339 / 348
# 0: 384x640 1 person, 1 bench, 26.4ms
# Speed: 2.5ms preprocess, 26.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 340 / 348
# 0: 384x640 1 person, 26.4ms
# Speed: 1.7ms preprocess, 26.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# count: 341 / 348
# 0: 384x640 1 person, 1 bench, 26.4ms
# Speed: 2.6ms preprocess, 26.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 342 / 348
# 0: 384x640 1 person, 26.3ms
# Speed: 2.1ms preprocess, 26.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# count: 343 / 348
# 0: 384x640 1 person, 26.4ms
# Speed: 2.1ms preprocess, 26.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# count: 344 / 348
# 0: 384x640 1 person, 26.3ms
# Speed: 1.7ms preprocess, 26.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 345 / 348
# 0: 384x640 1 bench, 26.4ms
# Speed: 2.1ms preprocess, 26.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# count: 346 / 348
# 0: 384x640 1 bench, 25.9ms
# Speed: 2.5ms preprocess, 25.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# count: 347 / 348
# 0: 384x640 1 bench, 25.0ms
# Speed: 3.5ms preprocess, 25.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
